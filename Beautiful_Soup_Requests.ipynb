# %%
import requests
url = 'https://www.codingdojo.com'
response = requests.get(url)
type(response)
# Out:
# requests.models.Response

# %%
# Obtain a response status code
response.status_code
# Out:
# 200

# %%
# Simple argument to display success or error
if response.status_code == 200:
    print("Success!")
else:
    print("An error occurred.")
# Out:
# Success!

# %%
# Obtain headers from response (First 100 chars)
str(response.headers)[:100]
# Out:
# "{'Date': 'Wed, 20 Mar 2024 19:07:13 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Enco"

# %%
# Obtain final url from response
response.url
# Out:
# 'https://www.codingdojo.com/'

# %%
# Obtain encoding from response
response.encoding
# Out:
# 'UTF-8'

# %%
# Obtain content from response
response.content[:500]
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n    <head>\n        <title>Coding Dojo - Software Development Coding Bootcamp</title>\n        <link rel="shortcut icon" href="https://cutecdn.codingdojo.com/images/global/cd_profile_icon_favicon.ico" type="image/x-icon">\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1 minimum-scale=1.0">\n        <meta name="description" property="og:description" '

# %%
from bs4 import BeautifulSoup
# Use BeautifulSoup to parse the HTML content
soup = BeautifulSoup(response.content)
# Using .prettify() to view the parsed HTML structure in a readable format
print(soup.prettify()[:2000])
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Coding Dojo - Software Development Coding Bootcamp
#   </title>
#   <link href="https://cutecdn.codingdojo.com/images/global/cd_profile_icon_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1 minimum-scale=1.0" name="viewport"/>
#   <meta content="Interested in starting your new career in tech? Learn to code at one of the top coding bootcamps. Build your first website and app in a matter of weeks. We teach Python, Java, .NET, iOS, Javascript and more. Online learning options and scholarships available. Learn more today!" name="description" property="og:description"/>
#   <meta content="Coding Dojo - Software Development Coding Bootcamp" name="title" property="og:title"/>
#   <meta content="" name="author"/>
#   <link href="https://www.codingdojo.com/" rel="canonical"/>
#   <link href="https://bat.bing" rel="dns-prefetch"/>
#   <link href="https://a.omappapi.com" rel="dns-prefetch"/>
#   <link href="https://global.localizecdn.com" rel="dns-prefetch"/>
#   <link href="https://player.vimeo.com/" rel="dns-prefetch"/>
#   <link href="https://static.hsappstatic.net" rel="dns-prefetch"/>
#   <link href="https://www.clarity.ms" rel="dns-prefetch"/>
#   <link href="https://cdn.codingdojo.com" rel="preconnect"/>
#   <link href="https://cdn2.codingdojo.com" rel="preconnect"/>
#   <link href="https://cutecdn.codingdojo.com" rel="preconnect"/>
#   <link href="https://js.intercomcdn.com" rel="preconnect"/>
#   <link href="https://metrics.codingdojo.com" rel="preconnect"/>
#   <link href="https://cdn.codingdojo.com" rel="dns-prefetch"/>
#   <link href="https://cdn2.codingdojo.com" rel="dns-prefetch"/>
#   <link href="https://cutecdn.codingdojo.com" rel="dns-prefetch"/>
#   <link href="https://js.intercomcdn.com" rel="dns-prefetch"/>
#   <link href="https://metrics.codingdojo.com" rel="dns-prefetch"/>
#   <link as="font" href="https://c

# %%
soup.title
# Out:
# <title>Coding Dojo - Software Development Coding Bootcamp</title>

# %%
soup.head
# Out:
# <head>
# <title>Coding Dojo - Software Development Coding Bootcamp</title>
# <link href="https://cutecdn.codingdojo.com/images/global/cd_profile_icon_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1 minimum-scale=1.0" name="viewport"/>
# <meta content="Interested in starting your new career in tech? Learn to code at one of the top coding bootcamps. Build your first website and app in a matter of weeks. We teach Python, Java, .NET, iOS, Javascript and more. Online learning options and scholarships available. Learn more today!" name="description" property="og:description"/>
# <meta content="Coding Dojo - Software Development Coding Bootcamp" name="title" property="og:title"/>
# <meta content="" name="author"/>
# <link href="https://www.codingdojo.com/" rel="canonical"/>
# <link href="https://bat.bing" rel="dns-prefetch"/>
# <link href="https://a.omappapi.com" rel="dns-prefetch"/>
# <link href="https://global.localizecdn.com" rel="dns-prefetch"/>
# <link href="https://player.vimeo.com/" rel="dns-prefetch"/>
# <link href="https://static.hsappstatic.net" rel="dns-prefetch"/>
# <link href="https://www.clarity.ms" rel="dns-prefetch"/>
# <link href="https://cdn.codingdojo.com" rel="preconnect"/>
# <link href="https://cdn2.codingdojo.com" rel="preconnect"/>
# <link href="https://cutecdn.codingdojo.com" rel="preconnect"/>
# <link href="https://js.intercomcdn.com" rel="preconnect"/>
# <link href="https://metrics.codingdojo.com" rel="preconnect"/>
# <link href="https://cdn.codingdojo.com" rel="dns-prefetch"/>
# <link href="https://cdn2.codingdojo.com" rel="dns-prefetch"/>
# <link href="https://cutecdn.codingdojo.com" rel="dns-prefetch"/>
# <link href="https://js.intercomcdn.com" rel="dns-prefetch"/>
# <link href="https://metrics.codingdojo.com" rel="dns-prefetch"/>
# <link as="font" href="https://cutecdn.codingdojo.com/css/vendors/MyFontsWebfontsKit.min.css" rel="preload"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://metrics.codingdojo.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-PPFN88D');</script>
# <!-- End Google Tag Manager -->
# <!-- Detect if user has blocked tracking pixels -->
# <script type="text/javascript">window.addEventListener("load",function(){var e=new Date;e.setTime(e.getTime()+36e5);window.google_tag_manager?(console.log("Google Tag Manager is loaded"),document.cookie="is_gtm_blocked=false;expires="+e+";path=/;secure;"):(console.log("Google Tag Manager is not loaded"),document.cookie="is_gtm_blocked=true;expires="+e+";path=/;secure;")},!1);</script>
# <!-- eof Detect if user has blocked GTM  -->
# <!-- Sentry IO-->
# <script crossorigin="anonymous" integrity="sha384-wF7Jc4ZlWVxe/L8Ji3hOIBeTgo/HwFuaeEfjGmS3EXAG7Y+7Kjjr91gJpJtr+PAT" src="https://browser.sentry-cdn.com/5.15.5/bundle.min.js"></script>
# <script>let project_environment = "production";</script>
# <script src="https://cutecdn.codingdojo.com/js/custom/coding_dojo_sentry_script.js"></script>
# <!--End of sentry IO-->
# <script> var nearest_campus = ""; const page = "home";</script>
# <link href="https://cdn.codingdojo.com/assets/new_designs/css/minify/latest_optimize_top_home_minify.min.css?v=6.10.3" media="all" rel="stylesheet"/>
# <link href="https://cdn.codingdojo.com/assets/new_designs/css/minify/latest_optimize_below_home_minify.min.css?v=6.10.3" media="all" rel="stylesheet"/>
# <!-- Structured Data Mark-up Schema -->
# </head>

# %%
soup.body
# Out:
# <body class="home main-content-wrap">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://metrics.codingdojo.com/ns.html?id=GTM-PPFN88D" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- New Admission Process 2.0 -->
# <div class="header_block home" id="header_box">
# <div class="" id="main_nav_container">
# <ul id="user_type_list">
# <li>
# <span class="dropdown_title enterprise">For Enterprise</span>
# <div class="dropdown_menu" id="enterprise_list">
# <ul>
# <li>
# <h4>FOR BUSINESS</h4>
# <div>
# <a href="/corporate-training">Corporate Training</a>
# </div>
# </li>
# </ul>
# </div>
# </li>
# <li><a href="https://login.codingdojo.com/" target="_blank">Student Login</a></li>
# </ul>
# <div class="main_nav_block">
# <a class="cd_logo uses_sprite vertical_centered" href="/">
# <img alt="coding-dojo-logo" src="https://cutecdn.codingdojo.com/svg_images/logos/coding_dojo_white_new_version.svg"/>
# </a>
# <ul class="nav_option_block">
# <li class="mobile_nav_close"><button class="btn close_nav_btn"></button></li>
# <li class="has_carret">
# <a href="javascript:void(0)">Programs</a>
# <i class="fas fa-chevron-down"></i>
# <div class="dropdown_menu" id="program_courses">
# <ul>
# <li>
# <h4><a class="linked_title" href="/software-dev-comparison">Software Development</a> <i class="fas fa-chevron-down"></i></h4>
# <div>
# <a class="has_margin" href="/software-development-full-time">Online Full-Time</a>
# <a href="/software-development-part-time-accelerated">Online Part-Time Accelerated <span class="label campus_open">POPULAR!</span></a>
# </div>
# </li>
# </ul>
# </div>
# </li>
# <li class="has_carret">
# <a href="javascript:void(0)">Admissions</a>
# <i class="fas fa-chevron-down"></i>
# <div class="dropdown_menu" id="admissions_list">
# <ul>
# <li>
# <h4>Admissions <i class="fas fa-chevron-down"></i></h4>
# <div>
# <a class="ada_cta_button" href="javascript:void(0);">Connect with Admissions</a>
# <a href="/faq">FAQ</a>
# </div>
# </li>
# <li>
# <h4>Tuition &amp; Financing <i class="fas fa-chevron-down"></i></h4>
# <div>
# <a href="/financing">Financing</a>
# <a href="/scholarship-application">Scholarships</a>
# </div>
# </li>
# </ul>
# <ul>
# <li>
# <span>Still Have Questions?</span>
# <a class="ada_cta_button" href="javascript:void(0);">Speak to An Advisor</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has_carret">
# <a href="javascript:void(0)">About</a>
# <i class="fas fa-chevron-down"></i>
# <div class="dropdown_menu" id="about_list">
# <ul>
# <li>
# <h4>Why Coding Dojo <i class="fas fa-chevron-down"></i></h4>
# <div>
# <a href="/dojo-difference">The Dojo Difference</a>
# <a href="/learning-science">Our Learning Science</a>
# </div>
# </li>
# <li>
# <h4>Company <i class="fas fa-chevron-down"></i></h4>
# <div>
# <a href="/join-our-team">Careers</a>
# <a href="/awards">Awards</a>
# <a href="/press">Press</a>
# <a href="/university-partnership">University Partnership</a>
# </div>
# </li>
# <li>
# <h4>Curriculum <i class="fas fa-chevron-down"></i></h4>
# <div>
# <a href="/what-is-python-programming">Python</a>
# <a href="/what-is-the-javascript-stack">Javascript</a>
# <a href="/why-learn-java-programming">Java</a>
# <a href="/why-learn-asp-net-core">.NET/C#</a>
# </div>
# </li>
# </ul>
# </div>
# </li>
# <li class="has_carret">
# <a href="javascript:void(0)">Resources</a>
# <i class="fas fa-chevron-down"></i>
# <div class="dropdown_menu resources_list">
# <ul class="sub_nav">
# <li>
# <h4>Free Resources <i class="fas fa-chevron-down"></i></h4>
# <div>
# <a href="https://algorithm.codingdojo.com/" target="_blank">Algorithm App <span class="label campus_open">Practice Coding!</span></a>
# <a href="/blog">Blog</a>
# </div>
# </li>
# <li>
# <h4>Free Events <i class="fas fa-chevron-down"></i></h4>
# <div>
# <a href="/intro-to-web-development">Intro to Web Development</a>
# <a href="/intro-to-python">Intro to Python</a>
# </div>
# </li>
# </ul>
# </div>
# </li>
# <li class="show_in_mobile has_carret">
# <a href="javascript:void(0)">For Enterprise</a>
# <i class="fas fa-chevron-down"></i>
# <div class="dropdown_menu" id="partnerships">
# <a href="/corporate-training">Corporate Training</a>
# </div>
# </li>
# <li class="show_in_mobile has_carret"><a href="https://login.codingdojo.com/" target="_blank">Student Login</a></li>
# <li class="mobile_cta_btn">
# <a class="open_house_btn campus_tour_button cta_wht_btn_light" href="javascript:void(0)">Open House</a>
# <a class="cta_blue_btn apply_btn_nav" href="/apply" target="_blank">Apply Now</a>
# </li>
# </ul>
# <button aria-label="Mobile Button" id="mobile_hamburger" type="button">
# <span></span>
# <span></span>
# <span></span>
# </button>
# </div>
# </div><!-- END main_nav_block -->
# <div class="splash_image_block home" id="splash_image_block">
# <div id="video_parent">
# <div id="video_mask"></div>
# <img alt="coding-dojo-homepage-splash-image" id="video_image_cover" src="https://cutecdn.codingdojo.com/new_design_image/home/optimized/coding-dojo-homepage-splash-image.png"/>
# <video id="splash_main_video" loop="" muted="" playsinline="">
# <source>
# </source></video>
# </div>
# <div id="splash_link">
# <header>
# <div id="future_links">
# <div class="radial" id="radial_ring_code"></div>
# <div class="radial" id="radial_frame"></div>
# <div class="radial" id="radial_ring_1"></div>
# <div class="radial" id="radial_ring_2"></div>
# <div class="radial" id="radial_ring_3"></div>
# <div class="blue_line_parent">
# <div class="blue_line" id="top_blue_line"></div>
# </div>
# <div class="radial" id="link_parent">
# <div class="invisible"></div>
# <a aria-label="watch coding dojo redefine possible video" class="watch_video_button cta_blue_button cta_disabled" href="javascript:void(0);"></a>
# <div class="invisible"></div>
# </div>
# </div>
# <div class="title_block" id="desktop_version">
# <h1>Launch Your Career Path in Tech</h1>
# <h2>Learn digital skills to enhance your career path</h2>
# <div class="cta_btn_block">
# <a class="cta_blue_btn apply_btn_banner cta_disabled" href="javascript:void(0)"><span></span>Get Free Course Packet</a>
# </div>
# </div>
# </header>
# </div>
# </div><!-- END splash_image_block -->
# </div>
# <div class="overlay_container_effect"></div>
# <div class="page_data_carrier">
# <div id="company_icons_section">
# <p><span>Established in 2012—</span> we have over 13K+ global alumni</p>
# <p>1600+ Course Reviews <span></span></p>
# <p>Where you might have seen us:<span>Fast Company | Good Morning America | Forbes</span></p>
# </div>
# <div id="coding_bootcamps_banner">
# <h2>Redefine Possible</h2>
# <h3>Not all Coding Bootcamps are Created Equal.</h3>
# <ul>
# <li>
# <span class="years_service"></span>
# <div>
# <h3>10+ Years</h3>
# <p>of coding bootcamp excellence &amp; expertise</p>
# <p class="mobile_text">of coding bootcamp excellence &amp; expertise</p>
# </div>
# </li>
# <li>
# <span class="days_graduates"></span>
# <div>
# <h3>13k+</h3>
# <p>Global Alumni</p>
# <p class="mobile_text">graduates since 2012</p>
# </div>
# </li>
# <li>
# <span class="countries_global"></span>
# <div>
# <h3>20+</h3>
# <p>countries in Coding Dojo's global footprint</p>
# <p class="mobile_text">countries in Coding Dojo's global footprint</p>
# </div>
# </li>
# <li>
# </li>
# </ul>
# </div>
# <div id="programs_block">
# <h2>Discover our Bootcamps</h2>
# <ul id="course_blocks_container">
# <li>
# <span class="api_icon"><img alt="web-development-courses-icon" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/courses/twentyfour-seven-cohort-access-icon.svg" height="41" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="37"/></span>
# <h3>Software Development</h3>
# <p>Our flagship 3-stack coding bootcamp, delivered since 2012</p>
# <ul>
# <li>
# <h4>Online Full-Time <span class="date_badge">APR 2024</span></h4>
# <span><span>16 WEEKS</span><span>MON-FRI</span><span>70-90 HRS/WK</span></span>
# </li>
# <li>
# <h4>Online Part-Time Accelerated <span class="date_badge">APR 2024</span></h4>
# <span><span>18-34 WEEKS</span><span>30 HRS/WK</span></span>
# </li>
# </ul>
# <a href="/software-dev-comparison" target="_blank">
# <span class="api_icon"><img alt="web-development-courses-icon" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/courses/twentyfour-seven-cohort-access-icon.svg" height="41" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="37"/></span>
# <span>Let's Go</span>
# <div>
# <span class="title">Software Development</span>
# <p>Our flagship 3-stack coding bootcamp, delivered since 2012</p>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div id="get_quick_answers_section">
# <h2>Have questions?</h2>
# <p>Give us a call <a href="tel:(844) 446-3656">(844) 446-3656</a>.</p>
# <div id="question_container">
# <div>
# <img alt="online-info-session-image" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/homepage/online-info-session-image.svg" height="152" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="152"/>
# <ul>
# <li><h4>Online Info Session</h4></li>
# <li><img alt="grey-check" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/homepage/grey-check.svg" height="11" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="16"/><span>Get a course recommendation</span></li>
# <li><img alt="grey-check" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/homepage/grey-check.svg" height="11" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="16"/><span>See how we teach</span></li>
# <li><img alt="grey-check" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/homepage/grey-check.svg" height="11" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="16"/><span>Meet your instructors</span></li>
# </ul>
# <a class="cta_blue_btn campus_tour_button cta_disabled" href="javascript:void(0);">Join the Open House</a>
# </div>
# <div>
# <img alt="admission-QA-image" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/homepage/admission-QA-image.svg" height="152" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="152"/>
# <ul>
# <li><h4>Admissions Q&amp;A</h4></li>
# <li><img alt="grey-check" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/homepage/grey-check.svg" height="11" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="16"/><span>See how the bootcamp works</span></li>
# <li><img alt="grey-check" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/homepage/grey-check.svg" height="11" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="16"/><span>Learn all our course options</span></li>
# <li><img alt="grey-check" class="lazy" data-src="https://cutecdn.codingdojo.com/svg_images/homepage/grey-check.svg" height="11" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="16"/><span>Discover custom financing options</span></li>
# </ul>
# <a class="cta_blue_btn ada_cta_button cta_disabled" href="javascript:void(0);">Schedule a Call</a>
# </div>
# </div>
# </div>
# <div id="faq_section">
# <h2>Frequently Asked Questions</h2>
# <ul>
# <li>
# <div class="accordion_title" data-accordion-id="0">
# <h3>Why Choose Coding Dojo?</h3>
# </div>
# <div class="accordion_content">
# <p>In ten years, Coding Dojo has helped over 13K+ global alumni study to kickstart their career path in tech.</p>
# </div>
# </li>
# <li>
# <div class="accordion_title" data-accordion-id="0">
# <h3>How Long Are Your Bootcamps?</h3>
# </div>
# <div class="accordion_content">
# <p>Depending on your program and your schedule, our bootcamps range from 16-36 weeks.</p>
# <ul>
# <li>Software Development: 16 - 34 weeks</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="accordion_title" data-accordion-id="0">
# <h3>How Much Do Your Bootcamps Cost?</h3>
# </div>
# <div class="accordion_content">
# <p>Depending on what you would like to learn and your financing, our bootcamps cost anywhere from $9,995 to $16,995.</p>
# </div>
# </li>
# </ul>
# </div>
# <!-- <div id="career_service_section">
#             <div class="container">
#                 <button class="video_modal_btn lazy-background" role="button" aria-label="video button" data-bs-toggle="modal" data-bs-target="#video_modal" data-video-link="https://www.youtube.com/embed/ppsJQpod0Qg?autoplay=1&playlist=ppsJQpod0Qg&loop=1"></button>
#                 <video preload="none" poster="https://cutecdn.codingdojo.com/new_design_image/home/maxresdefault.svg" width="auto" height="auto" muted loop>
#                     <source src="https://cutecdn.codingdojo.com/new_design_image/home/videos/coding-dojo-career-service.mp4" type="video/mp4">
#                 </video>
#             </div>
#         </div> -->
# <div class="" id="alumni_carousel_section">
# <div class="carousel slide" id="testimonial_carousel">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <div>
# <h4 class="lazy-background">By the end of each stack, it was amazing to see where I got to compared to where I was when I started. There were plenty of obstacles, but 'strength through struggle' will really go a long way for your growth as a developer.</h4>
# <div class="alumni_details_container">
# <h5><span>Matt N.</span><span>Online Full-Time Program, 2022</span></h5>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div>
# <h4 class="lazy-background">Once graduation approached I did feel great with everything I learned and knew I was capable of finding and starting a new journey with the skills I learned.</h4>
# <div class="alumni_details_container">
# <h5><span>Leiver A.</span><span>Online Part-Time Program, 2021</span></h5>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div>
# <h4 class="lazy-background">Coding Dojo provided me with the resources and instructions to problem-solve obstacles and properly prepare for the course. I utilized my cohort and the spaces they provide to collaborate or receive help.</h4>
# <div class="alumni_details_container">
# <h5><span>Danielle G.</span><span>Online Part-Time Program, 2022</span></h5>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-indicators">
# <button aria-current="true" aria-label="Slide 1" class="active" data-bs-slide-to="0" data-bs-target="#testimonial_carousel" type="button"></button>
# <button aria-label="Slide 2" data-bs-slide-to="1" data-bs-target="#testimonial_carousel" type="button"></button>
# <button aria-label="Slide 3" data-bs-slide-to="2" data-bs-target="#testimonial_carousel" type="button"></button>
# </div>
# <button class="left carousel-control-prev" data-bs-slide="prev" data-bs-target="#testimonial_carousel" type="button">
# <span aria-hidden="true" class="fas fa-chevron-left"></span>
# </button>
# <button class="right carousel-control-next" data-bs-slide="next" data-bs-target="#testimonial_carousel" type="button">
# <span aria-hidden="true" class="fas fa-chevron-right"></span>
# </button>
# </div>
# </div>
# <div class="lazy-background" id="course_packet_section">
# <div class="course_wrapper">
# <div class="left_packet">
# <img alt="Master Course Packet" class="lazy" data-src="https://cutecdn.codingdojo.com/new_design_image/course_packet/cp_master.png" height="324" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="279"/>
# <div class="packet_content">
# <h2>Download Our Master Course Packet</h2>
# <p>Dig deeper into Our Course Curriculum— our comprehensive curriculum allows graduates to work at companies regardless of the programming languages the business is built upon. <a href="/course-packets" target="_blank">View our course packet.</a></p>
# </div>
# </div>
# <div class="right_section" id="form_packet">
# <div class="form_info">
# <form action="/pages/send_course_packet" class="course_packet_form" method="POST">
# <input class="form-control" name="codingdojo" type="hidden" value="c5d20e6941252e11f895ea3513c11af2"/>
# <input class="form-control reference_url" name="reference_url" type="hidden" value=""/>
# <input name="utm_source" type="hidden" value=""/>
# <input name="utm_medium" type="hidden" value=""/>
# <input name="utm_campaign" type="hidden" value=""/>
# <input name="utm_content" type="hidden" value=""/>
# <input name="utm_term" type="hidden" value=""/>
# <input name="gclid" type="hidden" value=""/>
# <input name="fbclid" type="hidden" value=""/>
# <input class="packet_name form-control" name="full_name" placeholder="First and Last Name" type="text"/>
# <input class="packet_email form-control" name="email" placeholder="Email Address" type="email"/>
# <input class="packet_phone form-control" name="phone_number" placeholder="201-555-0123" type="tel"/>
# <input class="form-control page" name="page" type="hidden" value="home"/>
# <select class="cp_state form-control" name="state" title="Choose State">
# <option disabled="" selected="" value="default">Which state are you from?</option>
# <option value="99">Non-US Resident</option>
# <option value="1">Alabama</option>
# <option value="2">Alaska</option>
# <option value="3">Arizona</option>
# <option value="4">Arkansas</option>
# <option value="5">California</option>
# <option value="6">Colorado</option>
# <option value="7">Connecticut</option>
# <option value="8">Delaware</option>
# <option value="9">District of Columbia</option>
# <option value="10">Florida</option>
# <option value="11">Georgia</option>
# <option value="12">Hawaii</option>
# <option value="13">Idaho</option>
# <option value="14">Illinois</option>
# <option value="15">Indiana</option>
# <option value="16">Iowa</option>
# <option value="17">Kansas</option>
# <option value="18">Kentucky</option>
# <option value="19">Louisiana</option>
# <option value="20">Maine</option>
# <option value="21">Maryland</option>
# <option value="22">Massachusetts</option>
# <option value="23">Michigan</option>
# <option value="24">Minnesota</option>
# <option value="25">Mississippi</option>
# <option value="26">Missouri</option>
# <option value="27">Montana</option>
# <option value="28">Nebraska</option>
# <option value="29">Nevada</option>
# <option value="30">New Hampshire</option>
# <option value="31">New Jersey</option>
# <option value="32">New Mexico</option>
# <option value="33">New York</option>
# <option value="34">North Carolina</option>
# <option value="35">North Dakota</option>
# <option value="36">Ohio</option>
# <option value="37">Oklahoma</option>
# <option value="38">Oregon</option>
# <option value="39">Pennsylvania</option>
# <option value="40">Rhode Island</option>
# <option value="41">South Carolina</option>
# <option value="42">South Dakota</option>
# <option value="43">Tennessee</option>
# <option value="44">Texas</option>
# <option value="45">Utah</option>
# <option value="46">Vermont</option>
# <option value="47">Virginia</option>
# <option value="48">Washington</option>
# <option value="49">West Virginia</option>
# <option value="50">Wisconsin</option>
# <option value="51">Wyoming</option>
# </select>
# <input class="packet_type" name="packet_type" type="hidden" value="master"/>
# <label class="gdpr_label">
# <p>By clicking the button below, you consent to Coding Dojo using automated technology and/or pre-recorded means to call, text and e-mail you at the information above, including your wireless number, if provided, regarding educational services. You also agree to our "<a href="/site-terms" target="_blank">Site Terms</a>" and "<a href="/privacy-policy" target="_blank">Privacy Policy</a>". This consent is not required as a condition to purchase a good or services. Msg and data rates may apply.</p>
# </label>
# <div class="captcha">
# <input class="form-control" id="captcha_input" name="security_code" type="text"/>
# </div>
# <input class="cta_blue_btn" type="submit" value="I Agree - Submit"/>
# </form> </div>
# </div>
# </div>
# </div>
# <div class="page_description" id="featured_press">
# <h3>Featured Press</h3>
# <ul>
# <li><a href="https://www.goodmorningamerica.com/GMA3/video/alabama-pastor-finds-calling-84910771" target="_blank">Good Morning America</a></li>
# <li><a href="https://www.usatoday.com/story/money/2022/05/19/jobs-covid-recovery-economy-payrolls/9815663002/?gnt-cfr=1" target="_blank">USA Today</a></li>
# <li><a href="https://www.geekwire.com/2022/2022-geekwire-awards-revealed-community-celebrates-big-winners-in-pacific-nw-tech/" target="_blank">GeekWire</a></li>
# <li><a href="https://abc7news.com/12098242/" target="_blank">ABC7 San Francisco</a></li>
# <li><a href="https://www.dice.com/career-advice/5-things-to-do-if-youre-getting-into-the-cybersecurity-field" target="_blank">DICE</a></li>
# <li><a href="https://metrophiladelphia.com/coding-bootcamp/" target="_blank">Metro Philadelphia</a></li>
# <li><a href="https://www.fastcompany.com/90796737/education-brands-that-matter-2022" target="_blank">Fast Company</a></li>
# <li><a href="https://www.denver7.com/news/national-politics/the-race/why-millions-of-americans-are-quitting-their-jobs" target="_blank">ABC7 Denver</a></li>
# <li><a href="https://www.forbes.com/sites/annefield/2021/09/27/coding-boot-camp-for-the-formerly-incarcerated-from-coding-dojo-and-pfs/?sh=3911ce31a58d" target="_blank">Forbes</a></li>
# <li><a href="https://www.phoenixnewtimes.com/arts/why-upskilling-matters-aaron-soto-phoenix-12541240" target="_blank">Phoenix New Times</a></li>
# <li><a href="https://www.azcentral.com/story/opinion/op-ed/2021/12/17/thinking-career-change-what-learned-army-ranger-coding-boot-camp/6495442001/" target="_blank">The Arizona Republic</a></li>
# </ul>
# </div>
# <div id="about_us">
# <div class="container">
# <h2>Redefine Your Possible</h2>
# <p>A significant problem in tech education is that most bootcamps require students to have a significant background in coding just to join a program. We’ve crafted a curriculum that builds a solid foundation and provides support from our Career Services team.</p>
# </div>
# </div>
# </div>
# <!-- Course Packet Modal -->
# <div class="modal fade splash_course_packet_modal" id="home_course_packet" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content course-packet-contents">
# <div class="modal-body">
# <button aria-label="Close" class="close" data-bs-dismiss="modal" type="button"></button>
# <div class="course_packet_container">
# <div class="course_blocks">
# <img alt="Master Course Packet" class="offscreen_img" data-src="https://cutecdn.codingdojo.com/new_design_image/course_packet/cp_master.png" height="401" id="course_packet_image" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="354"/>
# </div>
# <div class="course_blocks">
# <img alt="Download Icon" class="cp_download_icon offscreen_img" data-src="https://cutecdn.codingdojo.com/new_design_image/global/icon/cp_download_icon.png" height="35" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" width="30"/>
# <h4>Master Course Packet</h4>
# <p>See all your course and curriculum options</p>
# <form action="/pages/send_course_packet" class="course_packet_form" method="POST">
# <input class="form-control" name="codingdojo" type="hidden" value="c5d20e6941252e11f895ea3513c11af2"/>
# <input class="form-control reference_url" name="reference_url" type="hidden" value=""/>
# <input name="utm_source" type="hidden" value=""/>
# <input name="utm_medium" type="hidden" value=""/>
# <input name="utm_campaign" type="hidden" value=""/>
# <input name="utm_content" type="hidden" value=""/>
# <input name="utm_term" type="hidden" value=""/>
# <input name="gclid" type="hidden" value=""/>
# <input name="fbclid" type="hidden" value=""/>
# <input class="packet_name form-control" name="full_name" placeholder="First and Last Name" type="text"/>
# <input class="packet_email form-control" name="email" placeholder="Email Address" type="email"/>
# <input class="packet_phone form-control" name="phone_number" placeholder="201-555-0123" type="tel"/>
# <input class="form-control page" name="page" type="hidden" value="home"/>
# <select class="cp_state form-control" name="state" title="Choose State">
# <option disabled="" selected="" value="default">Which state are you from?</option>
# <option value="99">Non-US Resident</option>
# <option value="1">Alabama</option>
# <option value="2">Alaska</option>
# <option value="3">Arizona</option>
# <option value="4">Arkansas</option>
# <option value="5">California</option>
# <option value="6">Colorado</option>
# <option value="7">Connecticut</option>
# <option value="8">Delaware</option>
# <option value="9">District of Columbia</option>
# <option value="10">Florida</option>
# <option value="11">Georgia</option>
# <option value="12">Hawaii</option>
# <option value="13">Idaho</option>
# <option value="14">Illinois</option>
# <option value="15">Indiana</option>
# <option value="16">Iowa</option>
# <option value="17">Kansas</option>
# <option value="18">Kentucky</option>
# <option value="19">Louisiana</option>
# <option value="20">Maine</option>
# <option value="21">Maryland</option>
# <option value="22">Massachusetts</option>
# <option value="23">Michigan</option>
# <option value="24">Minnesota</option>
# <option value="25">Mississippi</option>
# <option value="26">Missouri</option>
# <option value="27">Montana</option>
# <option value="28">Nebraska</option>
# <option value="29">Nevada</option>
# <option value="30">New Hampshire</option>
# <option value="31">New Jersey</option>
# <option value="32">New Mexico</option>
# <option value="33">New York</option>
# <option value="34">North Carolina</option>
# <option value="35">North Dakota</option>
# <option value="36">Ohio</option>
# <option value="37">Oklahoma</option>
# <option value="38">Oregon</option>
# <option value="39">Pennsylvania</option>
# <option value="40">Rhode Island</option>
# <option value="41">South Carolina</option>
# <option value="42">South Dakota</option>
# <option value="43">Tennessee</option>
# <option value="44">Texas</option>
# <option value="45">Utah</option>
# <option value="46">Vermont</option>
# <option value="47">Virginia</option>
# <option value="48">Washington</option>
# <option value="49">West Virginia</option>
# <option value="50">Wisconsin</option>
# <option value="51">Wyoming</option>
# </select>
# <input class="packet_type" name="packet_type" type="hidden" value="master"/>
# <label class="gdpr_label">
# <p>By clicking the button below, you consent to Coding Dojo using automated technology and/or pre-recorded means to call, text and e-mail you at the information above, including your wireless number, if provided, regarding educational services. You also agree to our "<a href="/site-terms" target="_blank">Site Terms</a>" and "<a href="/privacy-policy" target="_blank">Privacy Policy</a>". This consent is not required as a condition to purchase a good or services. Msg and data rates may apply.</p>
# </label>
# <div class="captcha">
# <input class="form-control" id="captcha_input" name="security_code" type="text"/>
# </div>
# <input class="cta_blue_btn" type="submit" value="I Agree - Submit"/>
# </form> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Promotional Video Modal -->
# <div aria-labelledby="" class="modal fade promotional_video_modal" id="" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-lg" role="document">
# <div class="modal-content">
# <a class="close_modal_btn" data-bs-dismiss="modal" href="#"></a>
# <div class="modal-body">
# <ul class="list-unstyled promotional_video_list">
# <li class="active"></li>
# <li>
# </li>
# <li>
# </li>
# <li>
# </li>
# <li>
# </li>
# <li>
# </li>
# <li>
# </li>
# <li>
# </li>
# <li>
# </li>
# <li>
# </li></ul>
# <div id="video_navigation_container">
# <a class="prev_video hidden" data-direction="prev" href="javascript:void(0)"><img alt="prev-video" class="offscreen_img" data-src="https://cutecdn.codingdojo.com/new_images/home/prev-video.png" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" style="height: 100%; width: 100%; object-fit: cover;"/></a>
# <a class="next_video" data-direction="next" href="javascript:void(0)"><img alt="next-video" class="offscreen_img" data-src="https://assets.codingdojo.com/new_images/home/next-video.png" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" style="height: 100%; width: 100%; object-fit: cover;"/></a>
# </div>
# </div>
# <div class="modal-footer">
# <ul class="list-unstyled promotional_video_thumbnail_list">
# <li class="video_thumbnail_item active">
# <div class="modal_footer_image main_thumbnail"></div>
# <span class="video_title">Coding Dojo</span>
# </li>
# <li class="video_thumbnail_item" data-iframe-id="210595248" data-iframe-src="https://player.vimeo.com/video/210595248?autoplay=0&amp;muted=1&amp;api=1&amp;player_id=210595248">
# <div class="modal_footer_image tamara_thumbnail"></div>
# <span class="video_title">Tamara Solarzano</span>
# </li>
# <li class="video_thumbnail_item" data-iframe-id="210596285" data-iframe-src="https://player.vimeo.com/video/210596285?autoplay=0&amp;api=1&amp;player_id=210596285">
# <div class="modal_footer_image justin_thumbnail"></div>
# <span class="video_title">Justin Fisher</span>
# </li>
# <li class="video_thumbnail_item" data-iframe-id="210596886" data-iframe-src="https://player.vimeo.com/video/210596886?autoplay=0&amp;api=1&amp;player_id=210596886">
# <div class="modal_footer_image sara_thumbnail"></div>
# <span class="video_title">Sara Wong</span>
# </li>
# <li class="video_thumbnail_item" data-iframe-id="210596709" data-iframe-src="https://player.vimeo.com/video/210596709??autoplay=0&amp;api=1&amp;player_id=210596709">
# <div class="modal_footer_image matt_thumbnail"></div>
# <span class="video_title">Matt Tucker</span>
# </li>
# <li class="video_thumbnail_item" data-iframe-id="210598427" data-iframe-src="https://player.vimeo.com/video/210598427??autoplay=0&amp;api=1&amp;player_id=210598427">
# <div class="modal_footer_image eric_thumbnail"></div>
# <span class="video_title">Eric Chen</span>
# </li>
# <li class="video_thumbnail_item" data-iframe-id="210595035" data-iframe-src="https://player.vimeo.com/video/210595035?autoplay=0&amp;api=1&amp;player_id=210595035">
# <div class="modal_footer_image ignacio_thumbnail"></div>
# <span class="video_title">Ignacio Rovirosa</span>
# </li>
# <li class="video_thumbnail_item" data-iframe-id="210597276" data-iframe-src="https://player.vimeo.com/video/210597276??autoplay=0api=1&amp;player_id=210597276">
# <div class="modal_footer_image robb_thumbnail"></div>
# <span class="video_title">John Robb</span>
# </li>
# <li class="video_thumbnail_item" data-iframe-id="210597631" data-iframe-src="https://player.vimeo.com/video/210597631?autoplay=0api=1&amp;player_id=210597631">
# <div class="modal_footer_image kyle_thumbnail"></div>
# <span class="video_title">Kyle Halterman</span>
# </li>
# <li class="video_thumbnail_item" data-iframe-id="210598159" data-iframe-src="https://player.vimeo.com/video/210598159?autoplay=0api=1&amp;player_id=210598159">
# <div class="modal_footer_image choi_thumbnail"></div>
# <span class="video_title">Eric Choi</span>
# </li>
# </ul>
# <div id="thumbnail_navigation_container">
# <a class="slide_list_btn slide_left_thumbnail_list_btn" data-slide-direction="left" href="javascript:void(0)"><img alt="filmstrip-left" class="offscreen_img" data-src="https://cutecdn.codingdojo.com/new_images/home/filmstrip-left.png" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" style="height: 100%; width: 100%; object-fit: cover;"/></a>
# <a class="slide_list_btn slide_right_thumbnail_list_btn" data-slide-direction="right" href="javascript:void(0)"><img alt="filmstrip-right" class="offscreen_img" data-src="https://cutecdn.codingdojo.com/new_images/home/filmstrip-right.png" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg" style="height: 100%; width: 100%; object-fit: cover;"/></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Video Modal -->
# <div class="modal video_modal fade" id="video_modal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <button aria-label="Close" class="close" data-bs-dismiss="modal" type="button"></button>
# <div class="modal-body">
# <div id="iframe_container">
# <iframe allow="autoplay; fullscreen" frameborder="0" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation" src=""></iframe>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Video Modal -->
# <div aria-hidden="true" class="modal fade video_modal" id="video_modal" tabindex="-1">
# <div class="modal-dialog modal-lg modal-dialog-centered">
# <div class="modal-content">
# <button aria-label="Close" class="close" data-bs-dismiss="modal" type="button"></button>
# <div id="iframe_container">
# <iframe allow="autoplay; fullscreen" allowfullscreen="" class="vimeo_video" frameborder="0" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation" src=""></iframe>
# </div>
# <script src="https://cutecdn.codingdojo.com/js/vendor/vimeo_player.js"></script>
# </div>
# </div>
# </div> <footer class="" id="footer">
# <div class="row_container">
# <div id="footer_menus_container">
# <ul>
# <li>DISCLOSURES</li>
# <li><a href="/institutional-disclosures" target="blank">Institutional Disclosures</a></li>
# </ul>
# <ul>
# <li>RESOURCES</li>
# <li><a href="https://algorithm.codingdojo.com/" target="blank">Algorithm App</a></li>
# <li><a href="/blog" target="blank">Blog</a></li>
# <li><a href="/course-packets" target="blank">Course Packets</a></li>
# <li><a href="https://cdn2.codingdojo.com/files/Master_Student_Catalog_2023_Revised_27_July_2023.pdf" target="blank">Catalog</a></li>
# </ul>
# <ul>
# <li>COMPANY</li>
# <li><a href="/join-our-team" target="blank">Careers</a></li>
# <li><a href="/faq" target="blank">FAQ</a></li>
# <li><a href="/university-partnership" target="blank">University Partnerships</a></li>
# <li><a href="/privacy-policy" target="blank">Privacy Policy</a></li>
# </ul>
# </div>
# <div id="contact_us_block">
# <p>Call Us at <span>(844) 446-3656</span></p>
# <p>from 5 AM to 6 PM PST or, send <a href="/contact-us" target="_blank">an email.</a></p>
# </div>
# <p id="newsletter_confirmation">Thank you for your interest in Coding Dojo!</p>
# <form action="/pages/newsletter_subscription" class="form_disabled" id="newsletter_footer" method="post">
# <h4>Sign-Up for the Latest News &amp; Resources</h4>
# <input class="form-control" name="codingdojo" type="hidden" value="c5d20e6941252e11f895ea3513c11af2"/>
# <input name="reference_url" type="hidden" value=""/>
# <input name="utm_source" type="hidden" value=""/>
# <input name="utm_medium" type="hidden" value=""/>
# <input name="utm_campaign" type="hidden" value=""/>
# <input name="utm_content" type="hidden" value=""/>
# <input name="utm_term" type="hidden" value=""/>
# <div class="captcha">
# <input class="form-control" id="captcha_input" name="security_code" type="text"/>
# </div>
# <div class="email_info_wrapper">
# <input name="email_address" placeholder="Enter Email Address " type="email"/>
# <input class="offscreen_background" type="submit" value="Sign Up"/>
# </div>
# <p class="policy_label">By submitting your information, you agree and accept the Coding Dojo's <a href="/site-terms" target="_blank">Terms of Use</a>, <a href="/cookie-policy" target="_blank">Cookie Policy</a> and <a href="/privacy-policy" target="_blank">Privacy Policy</a>.</p>
# </form>
# </div>
# <div class="last_row row_container">
# <div id="contact_us_block">
# <p>Call Us at <span>(844) 446-3656</span></p>
# <p>from 5 AM to 6 PM PST or, send <a href="/contact-us" target="_blank">an email.</a></p>
# </div>
# <div id="social_media_icons">
# <ul>
# <li><a class="twitter_icon" href="https://twitter.com/CodingDojoDotCo" target="_blank"><i class="fab fa-twitter"></i></a></li>
# <li><a class="fb_icon" href="https://www.facebook.com/CodingDojodotco" target="_blank"><i class="fab fa-facebook-f"></i></a></li>
# <li><a class="linkedin_icon" href="https://www.linkedin.com/school/codingdojo/" target="_blank"><i class="fab fa-linkedin-in"></i></a></li>
# <li><a class="instagram_icon" href="https://www.instagram.com/CodingDojoDotCo/" target="_blank"><i class="fab fa-instagram"></i></a></li>
# <li><a class="yt_icon" href="https://www.youtube.com/user/CodingDojoCo" target="_blank"><i class="fab fa-youtube"></i></a></li>
# </ul>
# </div>
# </div>
# <div class="copy_right_block">
# <p>©2024 All rights reserved. No information may be duplicated without Coding Dojo's permission. Coding Dojo is part of Colorado Technical University. Coding Dojo cannot guarantee employment, salary, or career advancement. Not all programs are available to residents of all states and certain foreign countries. The appearance of U.S. Department of Defense (DOD) visual information does not imply or constitute DOD endorsement. See the <a href="/institutional-disclosures" target="_blank">Institutional Disclosures</a> section for information on the agencies that approve and regulate the school's programs. <a href="https://cdn2.codingdojo.com/files/Coding_Dojo_Student_Grievance_Contact_Info_2-2024.pdf" target="_blank">View complaint procedures.</a></p>
# <p>1575 Garden of the Gods Road, Suite 100 Colorado Springs, CO 80907</p>
# <a href="/state-specific-privacy-policy#exercising_rights" target="_blank">Do Not Sell or Share My Info</a>
# </div>
# </footer>
# <div aria-label="Open Intercom Messenger" aria-live="polite" id="fake_intercom" onclick="initializeIntercom()" role="button" tabindex="0">
# <!-- FAKE INTERCOM - This will show for 5 seconds after page loaded to avoid low page site speed. -->
# <div class="intercom-lightweight-app-launcher-icon intercom-lightweight-app-launcher-icon-open">
# <svg viewbox="0 0 28 32" xmlns="http://www.w3.org/2000/svg"><path d="M28 32s-4.714-1.855-8.527-3.34H3.437C1.54 28.66 0 27.026 0 25.013V3.644C0 1.633 1.54 0 3.437 0h21.125c1.898 0 3.437 1.632 3.437 3.645v18.404H28V32zm-4.139-11.982a.88.88 0 00-1.292-.105c-.03.026-3.015 2.681-8.57 2.681-5.486 0-8.517-2.636-8.571-2.684a.88.88 0 00-1.29.107 1.01 1.01 0 00-.219.708.992.992 0 00.318.664c.142.128 3.537 3.15 9.762 3.15 6.226 0 9.621-3.022 9.763-3.15a.992.992 0 00.317-.664 1.01 1.01 0 00-.218-.707z"></path></svg>
# </div>
# </div>
# <div class="modal fade" id="campus_tours_modal" role="dialog">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <button class="close_modal" data-bs-dismiss="modal" type="button"></button>
# <div id="campus_tour_modal"></div>
# </div>
# </div>
# </div>
# <div class="modal fade" data-bs-backdrop="static" id="campus_tour_success_modal" role="dialog">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-body">
# <button class="close_modal" data-bs-dismiss="modal" type="button"></button>
# <h2>Reservation complete</h2>
# <p>Check your inbox for reservation confirmation.</p>
# <p>Our staff looks forward to meeting you!</p>
# </div>
# </div>
# </div>
# </div>
# <div class="lightbox">
# <div id="course_packet_modal">
# <div id="thank_you_message">
# <h3>Thank you!</h3>
# <p>Our course packet will soon be in your email inbox.</p>
# <p class="notice">Can't wait?</p>
# <a class="cta_blue_button" href="https://cdn2.codingdojo.com/files/master_course_packet.pdf" target="_blank">View the document now</a>
# </div>
# </div>
# </div>
# <div class="modal fade" id="get_course_packet_modal" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div id="content_wrapper">
# <h4>Thank You</h4>
# <p>Your Course Packet is on its way</p>
# <button data-bs-dismiss="modal" type="button">Continue Browsing</button>
# <span class="packet_link">Can't wait? See <a href="https://cdn2.codingdojo.com/files/master_course_packet.pdf" target="_blank">your packet</a> now</span>
# <span>Want to learn more? <a href="/open-house" target="_blank">Join an Open House</a></span>
# </div>
# </div>
# </div>
# </div> <div class="modal fade schedule_q_a_form_modal" id="schedule_q_a_form_modal">
# <div class="modal-dialog vertical_align_center" role="document">
# <div class="modal-content">
# <script>var state_id = '48';</script>
# <div id="international_qa_container">
# <div class="qa_tab_container">
# <!-- Hubspot QA Meeting Modal -->
# <div class="qa_tabs active" id="international_states_selection_tab">
# <form action="javascript:void(0);" id="international_states_form">
# <img alt="meetings-logo" class="offscreen_img" data-src="https://cutecdn.codingdojo.com/new_design_image/global/icon/meetings-logo.png" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg"/>
# <h3>Let's meet</h3>
# <p>Complete the form below to get started.</p>
# <label for="state_selection">
# <span>Which US state do you currently live in?</span>
# <select class="state_selection" name="state_selection">
# <option id="california_state" selected="" value="5">California</option>
# </select>
# </label>
# <label for="outside_us_checkbox">
# <input id="outside_us_checkbox" type="checkbox"/>
# <div></div>
# <span>I live outside of the US</span>
# </label>
# <input role="button" type="submit" value="Continue"/>
# </form>
# </div>
# <div class="qa_tabs qa_admission_tab" id="qa_admission_tab"></div>
# <div class="qa_tabs" id="international_admissions_process_tab">
# <div class="admissions_block">
# <img alt="international-admission-icon" class="offscreen_img" data-src="https://cutecdn.codingdojo.com/new_design_image/global/icon/international-admission-icon.png" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg"/>
# <h3>You're International! <span>We have a special admissions process for you.</span></h3>
# <p>Please email <a href="mailto:admissions@codingdojo.com">admissions@codingdojo.com</a> to connect with our admissions team.</p>
# <p class="has_margin">Please provide your name, program of interest, and how you intend on financing your bootcamp.</p>
# <p>In the meantime, you’re also free to join our next Open House</p>
# <p class="has_margin">to learn more about Coding Dojo.</p>
# <a class="form_btn campus_tour_button" href="javascript:void(0)" role="button">Join The Open House</a>
# <a class="form_btn back_btn" href="javascript:void(0)">Back</a>
# </div>
# </div>
# <div class="qa_tabs" id="admissions_unsupported_area_tab">
# <div class="admissions_block">
# <img alt="area-dont-serve-icon" class="offscreen_img" data-src="https://cutecdn.codingdojo.com/new_design_image/global/icon/area-dont-serve-icon.png" src="https://cutecdn.codingdojo.com/new_design_image/global/icon/white_image.jpg"/>
# <h3>Sorry! We don’t serve your state</h3>
# <p>Unfortunately we don't offer courses to residents of your area at this time.</p>
# <p class="has_margin">Please email <a href="mailto:admissions@codingdojo.com">admissions@codingdojo.com</a> for follow-up questions.</p>
# <p>In the meantime, you’re also free to join our next Open House</p>
# <p class="has_margin">to learn more about Coding Dojo.</p>
# <a class="form_btn campus_tour_button" href="javascript:void(0)" role="button">Join The Open House</a>
# <a class="form_btn back_btn" href="javascript:void(0)">Back</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> <!--Pages load fonts and jquery -->
# <link href="https://cutecdn.codingdojo.com/css/vendors/MyFontsWebfontsKit.min.css" media="all" rel="stylesheet"/>
# <script async="" src="https://cutecdn.codingdojo.com/js/custom/cd_async_scripts.min.js"></script>
# <!-- For lazy load of global assets -->
# <script defer="" type="text/javascript">
#         var link_src = [], international_phone_loaded = false; /*Create arrays for script and link to lazy load assets*/
#         window.addEventListener("load", function(){
#         var check_jquery = setInterval( function() {  /* DOCU: This function checks jquery if loaded the if true it will load the remaining assets */
#             let jquery_element = document.body.contains(document.getElementById("jquery_element"));
#             if (jquery_element == false){ return;}
#             clearInterval(check_jquery);
#                  /* DOCU: Load remaining assets for Home Page*/
#                 $("head").append('<link rel="stylesheet" type="text/css" href="https://cutecdn.codingdojo.com/css/vendors/fontawesome-all.min.css" />');
#                 $("head").append('<link rel="stylesheet" type="text/css" href="https://cutecdn.codingdojo.com/css/vendors/bootstrap-5.3.2.min.css" />');
#
#                 $("<script />",{async: true,type:"text/javascript",src:"https://cutecdn.codingdojo.com/js/vendor/bootstrap-5.3.2.min.js"}).appendTo("head");
#                 $("<script />",{async: true,type:"text/javascript",src:"https://cutecdn.codingdojo.com/js/vendor/vimeo_player.js"}).appendTo("head");
#                 $("<script />",{defer: true,type:"text/javascript",src:"https://cutecdn.codingdojo.com/js/vendor/intercom-banner-checker.min.js"}).appendTo("head");
#                 $("<script />",{defer: true,type:"text/javascript",src:"https://cdn.codingdojo.com/assets/new_designs/js/minify/latest_homepage_minify.min.js?v=6.10.3"}).appendTo("head");
#
#
#
#
#
#
#                                                                                                                                     }, 400 );
#         });
#     </script>
# <!--For tracking pixels-->
# <script type="text/javascript">let state_province = "Washington";</script>
# <!-- Coding defered scripts including lazyloading of images, localize widget, create custom scripts and styles and load intenational input -->
# <script defer="" src="https://cutecdn.codingdojo.com/js/custom/cd_defer_scripts.min.js"></script>
# <div class="modal fade" id="new_qa_modal" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body">
# <button aria-label="Close" class="close" data-bs-dismiss="modal" type="button"></button>
# <h3></h3>
# <p>We’ll call you right away when we’re back online.</p>
# <div>
# <label for="speak_asap_radio">
# <img alt="speak-with-us" src="https://cutecdn.codingdojo.com/new_design_image/global/svg/speak-with-us.svg"/>
# <p>Speak with us <span class="bold">by phone</span></p>
# <input class="ada_radio_input" id="speak_asap_radio" name="ada_radio_input" type="radio"/>
# </label>
# <label for="sched_qa_call_radio">
# <img alt="chat-with-us" src="https://cutecdn.codingdojo.com/new_design_image/global/svg/chat-with-us.svg"/>
# <p>Speak with us <span class="bold">by chat</span></p>
# <input class="ada_radio_input" id="sched_qa_call_radio" name="ada_radio_input" type="radio"/>
# </label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div aria-labelledby="myModalLabel" class="modal fade new_cpd_modal" id="new_course_packet_modal" role="dialog" tabindex="-1">
# <div class="modal-dialog vertical_align_center home" role="document">
# <div class="modal-content">
# <button aria-label="Close" class="close" data-bs-dismiss="modal" type="button"></button>
# <script charset="utf-8" src="//js.hsforms.net/forms/v2.js" type="text/javascript"></script>
# <script>
#     hbspt.forms.create({
#         region: "na1",
#         portalId: "5092698",
#         formId: "2bea41eb-85bd-4bd6-add2-97b93d635342"
#     });
# </script> </div>
# </div>
# </div>
# <div class="modal fade" id="hs_chilipiper_modal" tabindex="-1">
# <div class="modal-dialog vertical_align_center">
# <div class="modal-content">
# <div class="modal-body">
# <button aria-label="Close" class="close" data-bs-dismiss="modal" type="button"></button>
# <!--[if lte IE 8]>
#                 <script charset="utf-8" type="text/javascript" src="//js.hsforms.net/forms/v2-legacy.js"></script>
#                 <![endif]-->
# <script charset="utf-8" src="//js.hsforms.net/forms/v2.js" type="text/javascript"></script>
# <script>
#                     hbspt.forms.create({
#                         region: "na1",
#                         portalId: "5092698",
#                         formId: "06b21af7-99e8-4f0e-a380-eec680352ff8",
#                         onFormSubmit: function() {
#                             $('.hbspt-form').css('display','none');
#                             $('#hs_chilipiper_modal').modal('hide');
#                         }
#                     });
#
#                     function showHSForm(){
#                         $('#hs_chilipiper_modal').modal('show');
#                         $('.hbspt-form').css('display','');
#                     }
#                 </script>
# <!-- Chili Piper Meeting Modal -->
# <script src="https://js.na.chilipiper.com/marketing.js" type="text/javascript"></script>
# <script>
#                     // Listen for form submitted message
#                     window.addEventListener("message", (event) => {
#                         if (event.data.type === "hsFormCallback" && event.data.eventName === "onFormSubmit") {
#                             if(page == 'online_ab_landing_page_qa'){
#                                 $("#course_packet_success_modal").modal("show");
#                             }
#                             else{
#                                 var lead = event.data.data.reduce((obj, item) => Object.assign(obj, { [item.name]: item.value }), {});
#                                 ChiliPiper.submit("codingdojo", "dallas-pilot", {
#                                     map: true,
#                                     lead: lead,
#                                     closeOnOutside: true,
#                                 });
#                             }
#                         }
#                     });
#                 </script>
# </div>
# </div>
# </div>
# </div>
# </body>

# %%
print(soup.body.prettify()[:1000])
# Out:
# <body class="home main-content-wrap">
#  <!-- Google Tag Manager (noscript) -->
#  <noscript>
#   <iframe height="0" src="https://metrics.codingdojo.com/ns.html?id=GTM-PPFN88D" style="display:none;visibility:hidden" width="0">
#   </iframe>
#  </noscript>
#  <!-- End Google Tag Manager (noscript) -->
#  <!-- New Admission Process 2.0 -->
#  <div class="header_block home" id="header_box">
#   <div class="" id="main_nav_container">
#    <ul id="user_type_list">
#     <li>
#      <span class="dropdown_title enterprise">
#       For Enterprise
#      </span>
#      <div class="dropdown_menu" id="enterprise_list">
#       <ul>
#        <li>
#         <h4>
#          FOR BUSINESS
#         </h4>
#         <div>
#          <a href="/corporate-training">
#           Corporate Training
#          </a>
#         </div>
#        </li>
#       </ul>
#      </div>
#     </li>
#     <li>
#      <a href="https://login.codingdojo.com/" target="_blank">
#       Student Login
#      </a>
#     </li>
#    </ul>
#    <div class="main_nav_block">
#     <a class="cd_logo uses_spr

# %%
# Access tag content
print(soup.title.text)
# Out:
# Coding Dojo - Software Development Coding Bootcamp

# %%
# Access tag attribute
soup.a['href']
# Out:
# '/corporate-training'

# %%
# find all h2 tags
found_h2_tags = soup.find_all('h2')
len(found_h2_tags)
# Out:
# 8

# %%
# Display h2 tags
found_h2_tags
# Out:
# [<h2>Learn digital skills to enhance your career path</h2>,
#  <h2>Redefine Possible</h2>,
#  <h2>Discover our Bootcamps</h2>,
#  <h2>Have questions?</h2>,
#  <h2>Frequently Asked Questions</h2>,
#  <h2>Download Our Master Course Packet</h2>,
#  <h2>Redefine Your Possible</h2>,
#  <h2>Reservation complete</h2>]

# %%
# Make request
url = 'https://realpython.github.io/fake-jobs/' 
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
    print("Success!")
else:
    print("An error occurred.")
# Out:
# Success!

# %%
# Create soup object with the response content
soup = BeautifulSoup(response.content)
# Preview content
print(soup.body.prettify()[:500])
# Out:
# <body>
#  <section class="section">
#   <div class="container mb-5">
#    <h1 class="title is-1">
#     Fake Python
#    </h1>
#    <p class="subtitle is-3">
#     Fake Jobs for Your Web Scraping Journey
#    </p>
#   </div>
#   <div class="container">
#    <div class="columns is-multiline" id="ResultsContainer">
#     <div class="column is-half">
#      <div class="card">
#       <div class="card-content">
#        <div class="media">
#         <div class="media-left">
#          <figure class="image is-48x48">
#           <img a

# %%
# Extract and print all titles
for text in soup.find_all(['h1', 'h2']):
    print(text.get_text())
# Out:
#         Fake Python
#
# Senior Python Developer
# Energy engineer
# Legal executive
# Fitness centre manager
# Product manager
# Medical technical officer
# Physiological scientist
# Textile designer
# Television floor manager
# Waste management officer
# Software Engineer (Python)
# Interpreter
# Architect
# Meteorologist
# Audiological scientist
# English as a second language teacher
# Surgeon
# Equities trader
# Newspaper journalist
# Materials engineer
# Python Programmer (Entry-Level)
# Product/process development scientist
# Scientist, research (maths)
# Ecologist
# Materials engineer
# Historic buildings inspector/conservation officer
# Data scientist
# Psychiatrist
# Structural engineer
# Immigration officer
# Python Programmer (Entry-Level)
# Neurosurgeon
# Broadcast engineer
# Make
# Nurse, adult
# Air broker
# Editor, film/video
# Production assistant, radio
# Engineer, communications
# Sales executive
# Software Developer (Python)
# Futures trader
# Tour manager
# Cytogeneticist
# Designer, multimedia
# Trade union research officer
# Chemist, analytical
# Programmer, multimedia
# Engineer, broadcasting (operations)
# Teacher, primary school
# Python Developer
# Manufacturing systems engineer
# Producer, television/film/video
# Scientist, forensic
# Bonds trader
# Editorial assistant
# Photographer
# Retail banker
# Jewellery designer
# Ophthalmologist
# Back-End Web Developer (Python, Django)
# Licensed conveyancer
# Futures trader
# Counselling psychologist
# Insurance underwriter
# Engineer, automotive
# Producer, radio
# Dispensing optician
# Designer, fashion/clothing
# Chartered loss adjuster
# Back-End Web Developer (Python, Django)
# Forest/woodland manager
# Clinical cytogeneticist
# Print production planner
# Systems developer
# Graphic designer
# Writer
# Field seismologist
# Chief Strategy Officer
# Air cabin crew
# Python Programmer (Entry-Level)
# Warden/ranger
# Sports therapist
# Arts development officer
# Printmaker
# Health and safety adviser
# Manufacturing systems engineer
# Programmer, applications
# Medical physicist
# Media planner
# Software Developer (Python)
# Surveyor, land/geomatics
# Legal executive
# Librarian, academic
# Barrister
# Museum/gallery exhibitions officer
# Radiographer, diagnostic
# Database administrator
# Furniture designer
# Ship broker
